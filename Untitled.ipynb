# %%
import pandas as pd
import numpy as np
import plotly.express as px
import dash
import dash_html_components as html
import dash_core_components as dcc
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output, State

# %%
apart_t = pd.read_csv('아파트_매매가_상승_지수.csv',encoding='CP949',header=[0,1]) #csv파일을 읽어온다.
[apart_t.rename(columns={apart_t.columns[index][0]:apart_t.columns[index-1][0]},inplace=True) for index,i in enumerate(apart_t.columns) if index%2!=0]
apart_t.drop(apart_t.columns[1:4],axis=1,inplace=True) # 1 ~ 3번째 열 삭제
apart_t.rename(columns={'Unnamed: 0_level_1':'지역'},inplace=True) # 지역으로 이름변경
apart_t.dropna(axis=0,inplace=True) #지역의 null값 행 모두 제거
apart_t.set_index('지 역',inplace=True) # 지역 인덱스화
apart_t.index = apart_t.index.map(lambda x : x[0]) #지역 인덱스 튜플값 풀어주기

apart_i = pd.DataFrame(apart_t.iloc[:,0::2].values,columns=apart_t.columns[0::2].map(lambda x : x[0])) #지수별로 데이터프레임 생성
apart_f = pd.DataFrame(apart_t.iloc[:,1::2].values,columns=apart_t.columns[0::2].map(lambda x : x[0])) #변동률별로 데이터프레임 생성
apart_i.set_index(apart_t.index,inplace=True) #인덱스를 지역명으로 지정
apart_f.set_index(apart_t.index,inplace=True) #
apart_f=apart_f.transpose()
apart_i=apart_i.transpose()

# %%
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
app.layout = html.Div(
    [
        html.H3(id='test',style={'border':'1px black dotted'}),
        html.H1(id='test2',style={"border":'1px black solid'}),
        dcc.Dropdown(id='drop',options = [{'label':i,'value':i} for i in apart_t.index],multi=True),
        dcc.Dropdown(id='drop2',options = [{'label':i,'value':i} for i in apart_t.index]),
        dcc.RangeSlider( id="range_slider"),
        dcc.Graph(id='example'),
        dcc.Graph(figure=px.line(apart_f[['전국']]))
    ]
)

# %%
@app.callback(
    Output('example','figure'),
    Input('drop','value')
)
def update_graph(value):

    return px.line(apart_f[value])

# @app.callback(
#     Output('test','children'),
#     Input('drop','value')
# )
# def test(value):
#     i=list()
#     i.append(value)
#     return i
app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [26/Jun/2021 16:38:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2021 16:38:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2021 16:38:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2021 16:38:05] "GET /_favicon.ico?v=1.20.0 HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
# ...
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2895, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas\_libs\index.pyx", line 70, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\index.pyx", line 101, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1675, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1683, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: None
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\admin\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1079, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\Users\admin\anaconda3\lib\site-packages\dash\dash.py", line 1010, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-125-c40f413157b6>", line 7, in update_graph
#     return px.line(apart_f[value])
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\frame.py", line 2902, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "C:\Users\admin\anaconda3\lib\site-packages\pandas\core\indexes\base.py", line 2897, in get_loc
#     raise KeyError(key) from err
# KeyError: None
# 127.0.0.1 - - [26/Jun/2021 16:38:05] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Jun/2021 16:38:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2021 16:38:09] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
# apart_month = pd.read_excel("아파트_월세_상승_지수.xlsx",header=10) #엑셀의 11번째 행부터 읽어들인다.
# apart_month.to_csv("아파트_월세_상승_지수.csv",index=False,encoding='CP949') #CSV 파일로 전환 index행을 만들지 않기위해 False
# apart_year = pd.read_excel("아파트_전세_상승_지수.xlsx",header=10) #엑셀의 11번째 행부터 읽어들인다.
# apart_year.to_csv("아파트_전세_상승_지수.csv",index=False,encoding='CP949') #CSV 파일로 전환 index행을 만들지 않기위해 False

# %%
apart_t = pd.read_csv('아파트_매매가_상승_지수.csv',encoding='CP949',header=[0,1]) #csv파일을 읽어온다. 
apart_m = pd.read_csv('아파트_월세_상승_지수.csv',encoding='CP949',header=[0,1]) #csv파일을 읽어온다. 
apart_y = pd.read_csv('아파트_전세_상승_지수.csv',encoding='CP949',header=[0,1]) #csv파일을 읽어온다.

# %%
[apart_y.rename(columns={apart_y.columns[index][0]:apart_y.columns[index-1][0]},inplace=True) for index,i in enumerate(apart_y.columns) if index%2!=0]
apart_y.drop(apart_y.columns[1:4],axis=1,inplace=True) # 1 ~ 3번째 열 삭제
apart_t.rename(columns={'Unnamed: 0_level_1':'지역'},inplace=True) # 지역으로 이름변경
apart_y.dropna(axis=0,inplace=True) #지역의 null값 행 모두 제거
apart_y.set_index('지 역',inplace=True) # 지역 인덱스화
apart_y.index = apart_y.index.map(lambda x : x[0]) #지역 인덱스 튜플값 풀어주기
apart_yi = pd.DataFrame(apart_y.iloc[:,0::2].values,columns=apart_y.columns[0::2].map(lambda x : x[0])) #지수별로 데이터프레임 생성
apart_yf = pd.DataFrame(apart_y.iloc[:,1::2].values,columns=apart_y.columns[0::2].map(lambda x : x[0])) #변동률별로 데이터프레임 생성
apart_yi.set_index(apart_y.index,inplace=True) #인덱스를 지역명으로 지정
apart_yf.set_index(apart_y.index,inplace=True) #

# %%
[apart_m.rename(columns={apart_m.columns[index][0]:apart_m.columns[index-1][0]},inplace=True) for index,i in enumerate(apart_m.columns) if index%2!=0]
apart_m.drop(apart_m.columns[1:4],axis=1,inplace=True) # 1 ~ 3번째 열 삭제
apart_m.rename(columns={'Unnamed: 0_level_1':'지역'},inplace=True) # 지역으로 이름변경
apart_m.dropna(axis=0,inplace=True) #지역의 null값 행 모두 제거
apart_m.set_index('지 역',inplace=True) # 지역 인덱스화
apart_m.index = apart_m.index.map(lambda x : x[0]) #지역 인덱스 튜플값 풀어주기
apart_mi = pd.DataFrame(apart_m.iloc[:,0::2].values,columns=apart_m.columns[0::2].map(lambda x : x[0])) #지수별로 데이터프레임 생성
apart_mf = pd.DataFrame(apart_m.iloc[:,3::2].values,columns=apart_m.columns[0::2].map(lambda x : x[0])) #변동률별로 데이터프레임 생성
apart_mi.set_index(apart_m.index,inplace=True) #인덱스를 지역명으로 지정
apart_mf.set_index(apart_m.index,inplace=True) #

# %%
apart_m.iloc[:,3::2]
# Out:
#       2015년 07월 2015년 08월 2015년 09월 2015년 10월 2015년 11월 2015년 12월 2016년 01월  \
#             변동률       변동률       변동률       변동률       변동률       변동률       변동률
# 지 역
# 전국        -0.14     -0.09     -0.08     -0.11     -0.12     -0.11     -0.06
# 수도권       -0.22     -0.16     -0.16     -0.17     -0.19     -0.18     -0.09
# 지방권       -0.06     -0.02      0.01     -0.06     -0.04     -0.04     -0.03
# 6대광역시     -0.08     -0.06     -0.06     -0.05      -0.1      -0.1     -0.03
# 5대광역시     -0.08     -0.05     -0.05     -0.05     -0.07     -0.11     -0.03
# 9개도       -0.12     -0.06     -0.05     -0.11     -0.06     -0.05     -0.06
# 8개도       -0.04      0.01      0.06     -0.06     -0.02      0.01     -0.03
# 서울         -0.3     -0.19     -0.18     -0.24     -0.32     -0.34     -0.14
# 경기         -0.2     -0.14     -0.17     -0.16     -0.11      -0.1     -0.08
# 인천        -0.11     -0.14     -0.08     -0.03     -0.23      -0.1     -0.02
# 부산        -0.15     -0.06      0.04         0     -0.15     -0.13     -0.09
# 대구         0.07         0     -0.02     -0.09      0.02     -0.05         0
# 광주         -0.2     -0.08     -0.13     -0.12     -0.12     -0.18     -0.05
# 대전        -0.02     -0.05     -0.29     -0.11      0.02     -0.13      0.09
# 울산        -0.04     -0.04      0.05      0.04     -0.04      0.01     -0.08
# 세종        -0.01     -0.19     -0.02     -0.16     -0.04     -0.08     -0.02
# 강원        -0.02     -0.02     -0.02     -0.05     -0.07     -0.07     -0.04
# 충북        -0.04     -0.11      0.03     -0.03      0.04      0.04      0.07
# 충남        -0.02      0.01      0.09      0.01     -0.07      0.02      -0.1
# 전북        -0.08      0.03      0.17      0.03      0.14      0.07         0
# 전남        -0.05     -0.09     -0.08     -0.15     -0.12     -0.09     -0.07
# 경북        -0.01      0.13      0.04     -0.07     -0.05      -0.1     -0.13
# 경남        -0.05     -0.01       0.1     -0.15     -0.05      0.06     -0.04
# 제주            0      0.17      0.07      0.36      0.36      0.57      0.59
#
#       2016년 02월 2016년 03월 2016년 04월  ... 2020년 03월 2020년 04월 2020년 05월  \
#             변동률       변동률       변동률  ...       변동률       변동률       변동률
# 지 역                                  ...
# 전국        -0.07     -0.06     -0.06  ...     -0.02     -0.02     -0.02
# 수도권       -0.09     -0.05     -0.06  ...     -0.04     -0.03     -0.02
# 지방권       -0.06     -0.07     -0.07  ...         0     -0.01     -0.02
# 6대광역시     -0.08     -0.08     -0.04  ...     -0.01     -0.01     -0.02
# 5대광역시     -0.08      -0.1     -0.07  ...     -0.01      0.01     -0.01
# 9개도       -0.05     -0.05     -0.08  ...     -0.03     -0.04     -0.02
# 8개도       -0.04     -0.03     -0.07  ...     -0.01     -0.03     -0.03
# 서울        -0.14     -0.06     -0.05  ...     -0.02         0     -0.01
# 경기        -0.06     -0.07     -0.09  ...     -0.05     -0.04     -0.01
# 인천        -0.09      0.03      0.07  ...     -0.04     -0.06     -0.06
# 부산        -0.07     -0.15      -0.1  ...     -0.03     -0.03     -0.07
# 대구         0.01     -0.08     -0.11  ...     -0.02         0      0.01
# 광주        -0.22     -0.14      0.07  ...     -0.02     -0.01         0
# 대전        -0.02      0.01     -0.05  ...     -0.11     -0.06     -0.06
# 울산        -0.15     -0.12      -0.1  ...      0.25       0.2      0.14
# 세종        -0.08     -0.08     -0.13  ...      0.38      0.26      0.19
# 강원        -0.07     -0.03     -0.02  ...     -0.02     -0.04     -0.03
# 충북        -0.03      0.12      0.18  ...      0.01     -0.04     -0.06
# 충남        -0.07     -0.09     -0.19  ...     -0.03     -0.02      0.01
# 전북        -0.04      0.06      0.04  ...      0.03     -0.04      0.02
# 전남        -0.02      0.03     -0.09  ...      0.01      0.01     -0.01
# 경북         0.01     -0.12     -0.17  ...     -0.02     -0.04     -0.01
# 경남        -0.06      -0.1      -0.1  ...         0     -0.05     -0.07
# 제주         0.06     -0.01     -0.02  ...      -0.1     -0.07     -0.11
#
#       2020년 06월 2020년 07월 2020년 08월 2020년 09월 2020년 10월 2020년 11월 2020년 12월
#             변동률       변동률       변동률       변동률       변동률       변동률       변동률
# 지 역
# 전국        -0.03     -0.02         0      0.02      0.03      0.06      0.22
# 수도권       -0.05     -0.05     -0.04         0         0         0      0.08
# 지방권       -0.01      0.02      0.03      0.03      0.06      0.12      0.35
# 6대광역시         0         0      0.03      0.01      0.06      0.12      0.36
# 5대광역시         0      0.01      0.05      0.01      0.07      0.14      0.43
# 9개도       -0.04     -0.03         0      0.04      0.01      0.02       0.1
# 8개도       -0.02         0         0      0.04      0.03      0.07      0.15
# 서울        -0.04     -0.07     -0.11     -0.06      0.02      0.05       0.1
# 경기        -0.05     -0.05         0      0.03     -0.01     -0.03      0.06
# 인천        -0.03     -0.03     -0.02      0.01      0.03      0.01      0.11
# 부산        -0.02     -0.02     -0.03     -0.04     -0.03     -0.05      0.03
# 대구            0         0      0.01      0.01      0.08      0.29      0.44
# 광주        -0.01      0.01     -0.02     -0.03         0     -0.03      0.15
# 대전         -0.1         0      0.32     -0.07     -0.02     -0.02      0.94
# 울산         0.22      0.13      0.09      0.36      0.53      0.85       1.3
# 세종         0.24      0.86      0.62      0.26      0.61      1.12      4.66
# 강원        -0.06      0.02       0.2      0.14      0.13      0.15      0.35
# 충북         0.16      0.07     -0.06      0.18         0      0.06      0.17
# 충남        -0.02      0.09      0.08      0.14      0.24      0.13      0.32
# 전북        -0.03     -0.09     -0.12     -0.14     -0.14     -0.15     -0.03
# 전남            0      0.01      0.15      0.06     -0.02      0.07      0.19
# 경북        -0.01     -0.01     -0.04      0.02      0.02      0.07      0.06
# 경남        -0.09     -0.05     -0.04      0.01      0.01      0.11       0.1
# 제주        -0.14      -0.1     -0.08     -0.09     -0.04     -0.03      0.03
#
# [24 rows x 66 columns]

# %%
apart_mf = pd.DataFrame(apart_m.iloc[:,1::2].values,columns=apart_m.columns[0::2].map(lambda x : x[0])) #변동률별로 데이터프레임 생성
# Out:
#       2015년 06월     2015년 07월        2015년 08월        2015년 09월         \
#              지수 변동률        지수    변동률        지수    변동률        지수    변동률
# 지 역
# 전국      102.502   -   102.362  -0.14   102.273  -0.09   102.196  -0.08
# 수도권     102.517   -    102.29  -0.22   102.129  -0.16   101.963  -0.16
# 지방권     102.483   -   102.426  -0.06   102.406  -0.02   102.415   0.01
# 6대광역시   101.681   -   101.597  -0.08   101.532  -0.06   101.473  -0.06
# 5대광역시   101.934   -   101.856  -0.08    101.81  -0.05   101.756  -0.05
# 9개도     102.341   -   102.222  -0.12   102.156  -0.06   102.101  -0.05
# 8개도     102.751   -   102.712  -0.04   102.718   0.01   102.782   0.06
# 서울      104.162   -   103.846   -0.3   103.645  -0.19   103.462  -0.18
# 경기      101.918   -   101.717   -0.2   101.577  -0.14     101.4  -0.17
# 인천      100.718   -   100.611  -0.11   100.474  -0.14   100.394  -0.08
# 부산      101.686   -   101.531  -0.15   101.467  -0.06   101.509   0.04
# 대구      101.668   -   101.741   0.07   101.745      0   101.721  -0.02
# 광주      102.361   -   102.151   -0.2    102.07  -0.08   101.932  -0.13
# 대전      102.076   -   102.056  -0.02   102.008  -0.05   101.715  -0.29
# 울산      102.378   -   102.333  -0.04   102.289  -0.04   102.336   0.05
# 세종      111.596   -    111.59  -0.01    111.38  -0.19   111.353  -0.02
# 강원      101.022   -   101.006  -0.02   100.981  -0.02   100.965  -0.02
# 충북      102.803   -   102.764  -0.04   102.653  -0.11   102.681   0.03
# 충남      102.545   -   102.527  -0.02   102.535   0.01   102.625   0.09
# 전북      100.105   -   100.029  -0.08   100.054   0.03   100.226   0.17
# 전남       101.95   -   101.895  -0.05   101.806  -0.09   101.724  -0.08
# 경북      102.869   -   102.854  -0.01   102.985   0.13   103.026   0.04
# 경남      105.583   -   105.527  -0.05    105.52  -0.01   105.625    0.1
# 제주       98.732   -    98.733      0    98.903   0.17    98.977   0.07
#
#       2015년 10월         ... 2020년 08월        2020년 09월        2020년 10월  \
#              지수    변동률  ...        지수    변동률        지수    변동률        지수
# 지 역                     ...
# 전국      102.081  -0.11  ...    97.813      0     97.83   0.02    97.862
# 수도권     101.791  -0.17  ...    98.881  -0.04    98.879      0    98.884
# 지방권     102.357  -0.06  ...    96.813   0.03    96.846   0.03    96.903
# 6대광역시   101.423  -0.05  ...     98.09   0.03    98.102   0.01    98.161
# 5대광역시   101.701  -0.05  ...    97.889   0.05    97.902   0.01    97.968
# 9개도     101.992  -0.11  ...    97.249      0    97.286   0.04    97.297
# 8개도     102.723  -0.06  ...    95.737      0    95.779   0.04    95.812
# 서울      103.214  -0.24  ...    98.946  -0.11    98.882  -0.06    98.904
# 경기      101.241  -0.16  ...    98.852      0    98.884   0.03    98.873
# 인천      100.366  -0.03  ...    98.872  -0.02    98.878   0.01    98.911
# 부산      101.504      0  ...    98.667  -0.03    98.624  -0.04    98.591
# 대구      101.631  -0.09  ...    99.962   0.01    99.968   0.01    100.05
# 광주      101.812  -0.12  ...    99.425  -0.02    99.391  -0.03    99.388
# 대전        101.6  -0.11  ...    98.664   0.32    98.593  -0.07    98.575
# 울산      102.374   0.04  ...     88.95   0.09    89.268   0.36    89.742
# 세종      111.172  -0.16  ...    102.56   0.62   102.827   0.26   103.455
# 강원      100.914  -0.05  ...    96.789    0.2    96.928   0.14    97.055
# 충북      102.646  -0.03  ...    97.182  -0.06    97.356   0.18    97.355
# 충남      102.634   0.01  ...    97.283   0.08    97.419   0.14    97.649
# 전북      100.257   0.03  ...    99.259  -0.12    99.122  -0.14    98.982
# 전남      101.573  -0.15  ...    99.375   0.15    99.433   0.06    99.411
# 경북      102.953  -0.07  ...    96.049  -0.04    96.064   0.02    96.087
# 경남      105.464  -0.15  ...    90.753  -0.04    90.759   0.01     90.77
# 제주       99.331   0.36  ...    94.283  -0.08      94.2  -0.09    94.162
#
#              2020년 11월        2020년 12월
#          변동률        지수    변동률        지수    변동률
# 지 역
# 전국      0.03    97.923   0.06    98.137   0.22
# 수도권        0    98.885      0    98.962   0.08
# 지방권     0.06     97.02   0.12     97.36   0.35
# 6대광역시   0.06    98.275   0.12    98.629   0.36
# 5대광역시   0.07    98.109   0.14     98.53   0.43
# 9개도     0.01    97.317   0.02    97.418    0.1
# 8개도     0.03    95.877   0.07    96.017   0.15
# 서울      0.02    98.951   0.05     99.05    0.1
# 경기     -0.01    98.845  -0.03    98.905   0.06
# 인천      0.03    98.921   0.01    99.026   0.11
# 부산     -0.03     98.54  -0.05    98.572   0.03
# 대구      0.08   100.341   0.29   100.785   0.44
# 광주         0    99.356  -0.03    99.507   0.15
# 대전     -0.02    98.559  -0.02     99.49   0.94
# 울산      0.53    90.504   0.85    91.678    1.3
# 세종      0.61   104.614   1.12    109.49   4.66
# 강원      0.13    97.204   0.15    97.548   0.35
# 충북         0    97.415   0.06    97.579   0.17
# 충남      0.24    97.779   0.13    98.092   0.32
# 전북     -0.14    98.835  -0.15    98.804  -0.03
# 전남     -0.02    99.484   0.07    99.676   0.19
# 경북      0.02    96.158   0.07    96.218   0.06
# 경남      0.01    90.874   0.11     90.96    0.1
# 제주     -0.04    94.131  -0.03    94.155   0.03
#
# [24 rows x 134 columns]
