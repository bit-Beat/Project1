# %%
from IPython.core.display import display, HTML 
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import pandas as pd
import numpy as np
import scipy.stats 

import json
import folium

import plotly.express as px

import dash
import dash_html_components as html
import dash_core_components as dcc
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output, State
from dash_router import Router
# Out:
# <ipython-input-2-1e17f2999edf>:11: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# <ipython-input-2-1e17f2999edf>:12: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc

# %%
################################################################ CSS 부분
selected = {'text-align':'left','margin':'8px 5px 8px 5px','width':'100%','padding':'8px 25px 8px 5px','border-radius': '.25rem','background-color':'#007bff','color':'white'}
select = {'text-align':'left','margin':'8px 5px 8px 5px','width':'100%','padding':'8px 25px 8px 5px','border':'0px','background-color':'white','color':'#007bff'}

# %%
################################################################ Header 부분
Title = html.H3("아파트 집값 상승세 추이 분석",style={'background-color':'white','font-weight':'600','text-align':'left','padding':'20px'}) ## Header Title 이름 
Header = html.Header([
    Title
],style={'border-bottom':'2px #d1d1d1 solid'})

################################################################ Tab 부분  
## Page-1의 상단탭
Tabs1 = html.Div([
            dbc.Nav([
            dbc.NavLink("Page1", style={'background-color':'white','border':'0px','text-align':'left','padding-left':'20px','width':'250px','color':'black','font-weight':'700'}),
            dbc.NavLink("Page2", href="/page-2",style={'background-color':'white','border':'0px','text-align':'left','width':'250px','color':'black'}),
            dbc.NavLink("Page3", href="/page-3",style={'background-color':'white','border':'0px','text-align':'left','width':'250px','color':'black'}),
    ])
],style={'padding':'5px'})

## Page-2의 상단탭
Tabs2 = html.Div([
            dbc.Nav([
            dbc.NavLink("Page1", href="/",style={'background-color':'white','border':'0px','text-align':'left','padding-left':'20px','width':'250px','color':'black'}),
            dbc.NavLink("Page2",style={'background-color':'white','border':'0px','text-align':'left','width':'250px','font-weight':'700','color':'black'}),
            dbc.NavLink("Page3", href="/page-3",style={'background-color':'white','border':'0px','text-align':'left','width':'250px','color':'black'}),
        ])
],style={'padding':'5px'})

## Page-3의 상단탭
Tabs3 = html.Div([
            dbc.Nav([
            dbc.NavLink("Page1", href="/",style={'background-color':'white','border':'0px','text-align':'left','padding-left':'20px','width':'250px','color':'black'}),
            dbc.NavLink("Page2", href="/page-2",style={'background-color':'white','border':'0px','text-align':'left','width':'250px','color':'black'}),
            dbc.NavLink("Page3", style={'background-color':'white','border':'0px','text-align':'left','width':'250px','font-weight':'700','color':'black'}),
        ])
],style={'padding':'5px'})


################################################################Tab Select <건드리지 마시오>
Tabs_select = html.Div(id='Tab_select',style = {'border-top':'2px #d1d1d1 solid','width':'100%','height':'30px'}) ## 디자인을 위해 삽입

################################################################ Tabs 부분
## Page-1의 좌측 탭
tabs = dcc.Tabs(id='tabs',
                   value='tab1_1',
                   vertical=True,
                   children=[
                       dcc.Tab(label='아파트 매매 상승률',value='tab1_1',style=select,selected_style=selected),
                       dcc.Tab(label='아파트 전세 상승률',value='tab1_2',style=select,selected_style=selected),
                       dcc.Tab(label='아파트 월세 상승률',value='tab1_3',style=select,selected_style=selected),
                       dcc.Tab(label='아파트 지수',value='tab1_4',style=select,selected_style=selected),
                       dcc.Tab(label='아파트 지도 비교',value='tab1_5',style=select,selected_style=selected)
                   ],style={'width':'auto'})

## Page-2의 좌측 탭
tabs2 = dcc.Tabs(id='tabs2',
                     value='tab2_1',
                     vertical=True,
                     children=[
                         dcc.Tab(label='GDP,인구 상관분석',value='tab2_1',style=select,selected_style=selected),
                         dcc.Tab(label='타지역 상관분석',value='tab2_2',style=select,selected_style=selected),
                     ],style={'width':'auto'})


################################################################ Main 부분
Main = html.Main(id='tab_contents',style={'height':'auto','display':''})

## Page-2의 Main 부분
Main2 = html.Main(id='tab_contents2',style={'height':'auto','display':''})

## Page-3의 Main 부분
Main3 = html.Main([
    html.Hr(),
    html.Label("수집 데이터",style={'font-weight':'bold','margin-bottom':'0px','margin-left':'10px'}),
    html.Hr(),
    html.Br(),
    html.Hr(),
    html.Label("학습 자료",style={'font-weight':'bold','margin-bottom':'0px','margin-left':'10px'}),
    html.Hr(),
],style={'height':'auto'})


################################################################ Footer 부분
Footer = html.Footer([
    "Koread.Univ HRD 산학협력단 빅데이터 교육 『 Pyeon Do-jun 』",
],style={'padding':'8px','height':'50px','text-align':'center','border':'2px solid #d1d1d1'},id='footer')

# %% [markdown]
# ## Tab_contents

# %%
####Tab1을 눌렀을 때 나올 화면
Tab1_div=html.Div([
    dbc.Row(dbc.Col(html.Div(""),style={'text-align':'center'})),
    dbc.Row([
        dbc.Col(html.Div([

            "Tab1_contents"

        ],style={'height':'100%','width':'100%','padding':'10px','padding-bottom':'100px','padding-top':'20px','border':'2px solid #d1d1d1'}),width=3),
        
        dbc.Col(html.Div([

        ],style={'width':'100%','height':'100%'}),width=9)
    ]),
    dbc.Row([
        dbc.Col(),
        dbc.Col() 
    ])
])

Tab2_div=html.Div([
    dbc.Row(dbc.Col(html.Div(""),style={'text-align':'center'})),
    dbc.Row([
        dbc.Col(html.Div([

            "Tab2_contents"

        ],style={'height':'100%','width':'100%','padding':'10px','padding-bottom':'100px','padding-top':'20px','border':'2px solid #d1d1d1'}),width=3),
        
        dbc.Col(html.Div([

        ],style={'width':'100%','height':'100%'}),width=9)
    ]),
    dbc.Row([
        dbc.Col(),
        dbc.Col() 
    ])
])

##
Tab3_div=html.Div([
    dbc.Row(dbc.Col(html.Div(""),style={'text-align':'center'})),
    dbc.Row([
        dbc.Col(html.Div([

            "Tab3_contents"

        ],style={'height':'100%','width':'100%','padding':'10px','padding-bottom':'100px','padding-top':'20px','border':'2px solid #d1d1d1'}),width=3),
        
        dbc.Col(html.Div([

        ],style={'width':'100%','height':'100%'}),width=9)
    ]),
    dbc.Row([
        dbc.Col(),
        dbc.Col() 
    ])
])

##
Tab4_div=html.Div([
    dbc.Row(dbc.Col(html.Div(""),style={'text-align':'center'})),
    dbc.Row([
        dbc.Col(html.Div([

            "Tab4_contents"

        ],style={'height':'100%','width':'100%','padding':'10px','padding-bottom':'100px','padding-top':'20px','border':'2px solid #d1d1d1'}),width=3),
        
        dbc.Col(html.Div([

        ],style={'width':'100%','height':'100%'}),width=9)
    ]),
    dbc.Row([
        dbc.Col(),
        dbc.Col() 
    ])
])

##
Tab5_div=html.Div([
    dbc.Row(dbc.Col(html.Div(""),style={'text-align':'center'})),
    dbc.Row([
        dbc.Col(html.Div([

            "Tab5_contents"

        ],style={'height':'100%','width':'100%','padding':'10px','padding-bottom':'100px','padding-top':'20px','border':'2px solid #d1d1d1'}),width=3),
        
        dbc.Col(html.Div([

        ],style={'width':'100%','height':'100%'}),width=9)
    ]),
    dbc.Row([
        dbc.Col(),
        dbc.Col() 
    ])
])

# %% [markdown]
# ## MainPage

# %%
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
app.title = '최종프로젝트' ## 타이틀 이름 설정
router = Router()
router.register_callbacks(app)

@router.route('/')
def page1():
    return html.Div(
    [
        html.Div(
            [
                Header,
                Tabs1,
                Tabs_select,
                
                html.Div([
                    dbc.Row([
                        dbc.Col([
                           html.Div(tabs,style={'width':'100%','height':'100%','border':'2px solid #d1d1d1'}) 
                        ],style={'width':'100%'},width=2),
                        dbc.Col([
                            Main
                        ])
                    ])
                ],style={'width':'100%','heigh':'100%','margin-bottom':'5px'}),
                
                Footer
            ],style={'height':'100%', 'width':'85vw','margin':'auto','background-color':'white',})
        
    ],style={'height':'100%', 'width':'100vw','background-color':'white','padding-top':'15px'}
)

# %% [markdown]
# ## Second Page

# %%
@router.route('/page-2')
def page2():
    return html.Div(
    [
        html.Div(
            [
                Header,
                Tabs2,
                Tabs_select,
                
                html.Div([
                    dbc.Row([
                        dbc.Col([
                           html.Div(tabs2,style={'width':'100%','height':'100%','border':'2px solid #d1d1d1'}) 
                        ],style={'width':'100%'},width=2),
                        dbc.Col([
                            Main2
                        ])
                    ])
                ],style={'width':'100%','heigh':'100%','margin-bottom':'5px'}),
                Footer,
            ],style={'height':'100%', 'width':'85vw','margin':'auto','background-color':'white',}
        )
        
    ],style={'height':'100%', 'width':'100vw','background-color':'white','padding-top':'15px'}
)

# %% [markdown]
# ## Third Page

# %%
@router.route('/page-3')
def page3():
    return html.Div(
    [
        html.Div(
            [
                Header,
                Tabs3,
                Tabs_select,
                
                html.Div([
                    dbc.Row([
                        dbc.Col([
                            Main3
                        ])
                    ])
                ],style={'width':'100%','heigh':'100%','margin-bottom':'5px'}),
                Footer,
            ],style={'height':'100%', 'width':'85vw','margin':'auto','background-color':'white',}
        )
        
    ],style={'height':'100%', 'width':'100vw','background-color':'white','padding-top':'15px'}
)

# %% [markdown]
# ## Call-backs and Run_server

# %%
@app.callback(
    Output('tab_contents', 'children'),
    Input('tabs', 'value')
)
def render_content(tab):
    if tab == 'tab1_1':
        return Tab1_div
    elif tab == 'tab1_2':
        return Tab2_div,
    elif tab == 'tab1_3':
        return Tab3_div,
    elif tab == 'tab1_4':
        return Tab4_div
    elif tab == 'tab1_5':
        return Tab5_div

app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Oct/2021 09:22:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:00] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:00] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2021 09:22:10] "POST /_dash-update-component HTTP/1.1" 200 -
